# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import matplotx

# %%
df = pd.read_csv(r"D:\OneDrive\Documents\Python_\GitHub\Pandas\countries_data.csv")
display(df)
# Out:
#               name            capital  population      area     region
# 0    South Georgia  King Edward Point          30    3903.0  Antarctic
# 1          Grenada       St. George's      112519     344.0   Americas
# 2      Switzerland               Bern     8654622   41284.0     Europe
# 3     Sierra Leone           Freetown     7976985   71740.0     Africa
# 4          Hungary           Budapest     9749763   93028.0     Europe
# ..             ...                ...         ...       ...        ...
# 245        Belgium           Brussels    11555997   30528.0     Europe
# 246         Israel          Jerusalem     9216900   20770.0       Asia
# 247    New Zealand         Wellington     5084300  270467.0    Oceania
# 248      Nicaragua            Managua     6624554  130373.0   Americas
# 249       Anguilla         The Valley       13452      91.0   Americas
#
# [250 rows x 5 columns]

# %%
df.rename(columns={'region': 'Continent'}, inplace=True)
df.columns = df.columns.str.title()
display(df)
df.dtypes
# Out:
#               Name            Capital  Population      Area  Continent
# 0    South Georgia  King Edward Point          30    3903.0  Antarctic
# 1          Grenada       St. George's      112519     344.0   Americas
# 2      Switzerland               Bern     8654622   41284.0     Europe
# 3     Sierra Leone           Freetown     7976985   71740.0     Africa
# 4          Hungary           Budapest     9749763   93028.0     Europe
# ..             ...                ...         ...       ...        ...
# 245        Belgium           Brussels    11555997   30528.0     Europe
# 246         Israel          Jerusalem     9216900   20770.0       Asia
# 247    New Zealand         Wellington     5084300  270467.0    Oceania
# 248      Nicaragua            Managua     6624554  130373.0   Americas
# 249       Anguilla         The Valley       13452      91.0   Americas
#
# [250 rows x 5 columns]
# Name           object
# Capital        object
# Population      int64
# Area          float64
# Continent      object
# dtype: object

# %%
europe = df[df['Continent'] == 'Europe']
display(europe)
continent = df.Continent.unique()
print(continent)
# Out:
#                        Name             Capital  Population         Area  \
# 2               Switzerland                Bern     8654622     41284.00
# 4                   Hungary            Budapest     9749763     93028.00
# 11                    Italy                Rome    59554023    301336.00
# 19                  Andorra    Andorra la Vella       77265       468.00
# 22                   France               Paris    67391582    551695.00
# 27          North Macedonia              Skopje     2077132     25713.00
# 31                 Guernsey      St. Peter Port       62999        78.00
# 33   Svalbard and Jan Mayen        Longyearbyen        2562     61399.00
# 34            Faroe Islands            Tórshavn       48865      1393.00
# 47           United Kingdom              London    67215293    242900.00
# 49                  Finland            Helsinki     5530719    338424.00
# 62                   Greece              Athens    10715549    131990.00
# 63                  Croatia              Zagreb     4047200     56594.00
# 67              Netherlands           Amsterdam    16655799     41850.00
# 70            Liechtenstein               Vaduz       38137       160.00
# 75                   Monaco              Monaco       39244         2.02
# 87               Montenegro           Podgorica      621718     13812.00
# 91                  Ukraine                Kyiv    44134693    603500.00
# 92              Isle of Man             Douglas       85032       572.00
# 95                 Bulgaria               Sofia     6927288    110879.00
# 97                  Germany              Berlin    83240525    357114.00
# 101                  Sweden           Stockholm    10353442    450295.00
# 104                  Russia              Moscow   144104080  17098242.00
# 107                  Cyprus             Nicosia     1207361      9251.00
# 111  Bosnia and Herzegovina            Sarajevo     3280815     51209.00
# 113                   Spain              Madrid    47351567    505992.00
# 114                Slovenia           Ljubljana     2100126     20273.00
# 118              San Marino  City of San Marino       33938        61.00
# 122                 Iceland           Reykjavik      366425    103000.00
# 123              Luxembourg          Luxembourg      632275      2586.00
# 139                 Belarus               Minsk     9398861    207600.00
# 140                  Latvia                Riga     1901548     64559.00
# 144               Gibraltar           Gibraltar       33691         6.00
# 145                 Denmark          Copenhagen     5831404     43094.00
# 152                 Czechia              Prague    10698896     78865.00
# 162                 Estonia             Tallinn     1331057     45227.00
# 163                 Romania           Bucharest    19286123    238391.00
# 169            Vatican City        Vatican City         451         0.44
# 171                 Austria              Vienna     8917205     83871.00
# 177                 Ireland              Dublin     4994724     70273.00
# 180                  Norway                Oslo     5379475    323802.00
# 181           Åland Islands           Mariehamn       29458      1580.00
# 189               Lithuania             Vilnius     2794700     65300.00
# 191                Slovakia          Bratislava     5458827     49037.00
# 194                 Moldova            Chișinău     2617820     33846.00
# 199                  Jersey        Saint Helier      100800       116.00
# 212                   Malta            Valletta      525285       316.00
# 216                  Kosovo            Pristina     1775378     10908.00
# 221                 Albania              Tirana     2837743     28748.00
# 223                  Serbia            Belgrade     6908224     88361.00
# 230                  Poland              Warsaw    37950802    312679.00
# 242                Portugal              Lisbon    10305564     92090.00
# 245                 Belgium            Brussels    11555997     30528.00
#
#     Continent
# 2      Europe
# 4      Europe
# 11     Europe
# 19     Europe
# 22     Europe
# 27     Europe
# 31     Europe
# 33     Europe
# 34     Europe
# 47     Europe
# 49     Europe
# 62     Europe
# 63     Europe
# 67     Europe
# 70     Europe
# 75     Europe
# 87     Europe
# 91     Europe
# 92     Europe
# 95     Europe
# 97     Europe
# 101    Europe
# 104    Europe
# 107    Europe
# 111    Europe
# 113    Europe
# 114    Europe
# 118    Europe
# 122    Europe
# 123    Europe
# 139    Europe
# 140    Europe
# 144    Europe
# 145    Europe
# 152    Europe
# 162    Europe
# 163    Europe
# 169    Europe
# 171    Europe
# 177    Europe
# 180    Europe
# 181    Europe
# 189    Europe
# 191    Europe
# 194    Europe
# 199    Europe
# 212    Europe
# 216    Europe
# 221    Europe
# 223    Europe
# 230    Europe
# 242    Europe
# 245    Europe
# ['Antarctic' 'Americas' 'Europe' 'Africa' 'Asia' 'Oceania']
